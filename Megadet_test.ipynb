# %%
# !pip install humanfriendly jsonpickle
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 2.4 MB/s eta 0:00:00
# ...

# %%
# !pip install torch==1.11.0 torchvision==0.11.2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.6/750.6 MB 1.3 MB/s eta 0:00:00
# ERROR: Could not find a version that satisfies the requirement torchvision==0.11.2 (from versions: 0.1.6, 0.1.7, 0.1.8, 0.1.9, 0.2.0, 0.2.1, 0.2.2, 0.2.2.post2, 0.2.2.post3, 0.12.0, 0.13.0, 0.13.1, 0.14.0, 0.14.1, 0.15.0, 0.15.1, 0.15.2)
# ERROR: No matching distribution found for torchvision==0.11.2

# %%
# !wget -O /content/md_v5a.0.0.pt https://github.com/ecologize/CameraTraps/releases/download/v5.0/md_v5a.0.0.pt
# !wget -O /content/md_v5b.0.0.pt https://github.com/ecologize/CameraTraps/releases/download/v5.0/md_v5b.0.0.pt
# Out:
# --2023-09-18 21:05:24--  https://github.com/ecologize/CameraTraps/releases/download/v5.0/md_v5a.0.0.pt
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/agentmorris/MegaDetector/releases/download/v5.0/md_v5a.0.0.pt [following]
# --2023-09-18 21:05:25--  https://github.com/agentmorris/MegaDetector/releases/download/v5.0/md_v5a.0.0.pt
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !git clone https://github.com/ecologize/CameraTraps
# !git clone https://github.com/microsoft/ai4eutils
# !git clone https://github.com/ultralytics/yolov5/
# !cd yolov5 && git checkout c23a441c9df7ca9b1f275e8c8719c949269160d1
# Out:
# Cloning into 'CameraTraps'...
# remote: Enumerating objects: 16964, done.
# remote: Counting objects: 100% (1810/1810), done.
# remote: Compressing objects: 100% (718/718), done.
# remote: Total 16964 (delta 1148), reused 1752 (delta 1090), pack-reused 15154
# Receiving objects: 100% (16964/16964), 187.10 MiB | 29.17 MiB/s, done.
# Resolving deltas: 100% (10344/10344), done.
# Cloning into 'ai4eutils'...
# remote: Enumerating objects: 787, done.
# remote: Counting objects: 100% (93/93), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 787 (delta 54), reused 52 (delta 37), pack-reused 694
# Receiving objects: 100% (787/787), 2.59 MiB | 6.69 MiB/s, done.
# Resolving deltas: 100% (469/469), done.
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15990, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 15990 (delta 15), reused 18 (delta 12), pack-reused 15967
# ...

# %%
import os
os.environ['PYTHONPATH'] += ":/content/ai4eutils"
os.environ['PYTHONPATH'] += ":/content/CameraTraps"
os.environ['PYTHONPATH'] += ":/content/yolov5"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from IPython.display import Image

# %%
# Define the path to the image
image_path = '/content/drive/My Drive/images/example.jpg'

# Display the image
Image(filename='/imagen_prueba.jpeg')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
images_dir = '/images_dir'

# Choose a location for the output JSON file
output_file_path = '/content/drive/My Drive/megadetector-results.json'

# %%
# !python /content/CameraTraps/detection/run_detector_batch.py md_v5a.0.0.pt "$images_dir" "$output_file_path" --recursive --output_relative_filenames --quiet
# Out:
# 1 image files found in the input directory
# PyTorch reports 0 available CUDA devices
# GPU available: False
# Using PyTorch version 2.0.1+cu118
# Fusing layers...
# Model summary: 574 layers, 139990096 parameters, 0 gradients
# Loaded model in 12.04 seconds
# Loaded model in 12.04 seconds
# 100% 1/1 [00:07<00:00,  7.64s/it]
# Finished inference for 1 images in 24.97 seconds (0.04 images per second)
# Output file saved at /content/drive/My Drive/megadetector-results.json
# Done!

# %%
# Render bounding boxes on our images
visualization_dir = '/content/visualized_images'
# !python /content/CameraTraps/visualization/visualize_detector_output.py "$output_file_path" "$visualization_dir" --confidence 0.2 --images_dir "$images_dir"
# Out:
# python3: can't open file '/content/CameraTraps/visualization/visualize_detector_output.py': [Errno 2] No such file or directory

# %%
# !pip install boto3
# !pip install unidecode
# !pip install pytesseract
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 2.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 24.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 10.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.1/143.1 kB 16.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.4
#     Uninstalling urllib3-2.0.4:
#       Successfully uninstalled urllib3-2.0.4
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.9/235.9 kB 4.1 MB/s eta 0:00:00
# ...

# %%
# Se importan las librerias necesarias.
import boto3
import pandas as pd
from IPython.display import display
from io import BytesIO
import requests
from PIL import Image, ImageDraw
import collections
import glob
from datetime import datetime as dt
import gc
import json
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import random
from unidecode import unidecode
import re
import cv2
import pytesseract
from datetime import datetime

# %%
# Importo Informacion del AccessKey.
accessKey = pd.read_csv("ANoguera_accessKeys.csv")

# Configura tus credenciales de AWS si aún no lo has hecho
boto3.setup_default_session(aws_access_key_id=accessKey["Access key ID"][0],
                           aws_secret_access_key=accessKey["Secret access key"][0],
                           region_name='us-east-2')

# Nombre del bucket
nombre_bucket_s3 = 's3-pfa'

# Crea un cliente de S3
s3 = boto3.client('s3')

# %%
# Obtengo todas las rutas de las imagenes en S3
paginator = s3.get_paginator('list_objects_v2')
pages = paginator.paginate(Bucket=nombre_bucket_s3)
objetos_s3 = []

for page in pages:
    for obj in page['Contents']:
        objetos_s3.append(obj['Key'])

# %%
# Veo imagenes random de sauce 2022.
sauce_2023 = [ruta for ruta in objetos_s3 if ruta.startswith("Muestreo ct sauce/CT S 2023")]

sauce_2023
# Out:
# ['Muestreo ct sauce/CT S 2023/',
#  'Muestreo ct sauce/CT S 2023/S1/S1 -a- (1).JPG',
#  'Muestreo ct sauce/CT S 2023/S1/S1 -a- (10).JPG',
#  'Muestreo ct sauce/CT S 2023/S1/S1 -a- (100).JPG',
#  'Muestreo ct sauce/CT S 2023/S1/S1 -a- (1000).JPG',
#  'Muestreo ct sauce/CT S 2023/S1/S1 -a- (1001).JPG',
#  'Muestreo ct sauce/CT S 2023/S1/S1 -a- (1002).JPG',
#  'Muestreo ct sauce/CT S 2023/S1/S1 -a- (1003).JPG',
#  'Muestreo ct sauce/CT S 2023/S1/S1 -a- (1004).JPG',
#  'Muestreo ct sauce/CT S 2023/S1/S1 -a- (1005).JPG',
#  'Muestreo ct sauce/CT S 2023/S1/S1 -a- (1006).JPG',
#  'Muestreo ct sauce/CT S 2023/S1/S1 -a- (1007).JPG',
#  'Muestreo ct sauce/CT S 2023/S1/S1 -a- (1008).JPG',
#  'Muestreo ct sauce/CT S 2023/S1/S1 -a- (1009).JPG',
#  'Muestreo ct sauce/CT S 2023/S1/S1 -a- (101).JPG',
#  'Muestreo ct sauce/CT S 2023/S1/S1 -a- (1010).JPG',
#  'Muestreo ct sauce/CT S 2023/S1/S1 -a- (1011).JPG',
#  'Muestreo ct sauce/CT S 2023/S1/S1 -a- (1012).JPG',
# ...

# %%
# !pip install awscli
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 16.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 548.2/548.2 kB 26.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.9
#     Uninstalling rsa-4.9:
#       Successfully uninstalled rsa-4.9
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.18.1
#     Uninstalling docutils-0.18.1:
#       Successfully uninstalled docutils-0.18.1
# ...

# %%
# !aws configure
# Out:
# AWS Access Key ID [None]: AKIAQK4VVXEURVMRLBNW
# AWS Secret Access Key [None]: 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
# Default region name [None]: us-east-2
# Default output format [None]:

# %%
# !aws s3 ls s3://s3-pfa/'Muestreo ct sauce'/'CT S 2023'/S1/
# Out:
# Streaming output truncated to the last 5000 lines.
# 2023-09-14 21:25:47    4194347 S1 -b- (2471).JPG
# 2023-09-14 21:25:49    4194209 S1 -b- (2472).JPG
# 2023-09-14 21:25:50    4173813 S1 -b- (2473).JPG
# 2023-09-14 21:25:51    4194323 S1 -b- (2474).JPG
# 2023-09-14 21:25:54    4193843 S1 -b- (2475).JPG
# 2023-09-14 21:25:55    4172295 S1 -b- (2476).JPG
# 2023-09-14 21:25:56    4193523 S1 -b- (2477).JPG
# 2023-09-14 21:25:57    4194557 S1 -b- (2478).JPG
# 2023-09-14 21:26:00    4173107 S1 -b- (2479).JPG
# 2023-09-14 21:26:04    4193290 S1 -b- (248).JPG
# 2023-09-14 21:26:07    4194589 S1 -b- (2480).JPG
# 2023-09-14 21:26:09    4195084 S1 -b- (2481).JPG
# 2023-09-14 21:26:11    4165845 S1 -b- (2482).JPG
# 2023-09-14 21:26:12    4193722 S1 -b- (2483).JPG
# 2023-09-14 21:26:13    4194516 S1 -b- (2484).JPG
# 2023-09-14 21:26:15    4167098 S1 -b- (2485).JPG
# 2023-09-14 21:26:17    4193837 S1 -b- (2486).JPG
# 2023-09-14 21:26:18    4194597 S1 -b- (2487).JPG
# ...

# %%
import subprocess
import boto3

# Replace these with your actual values
bucket_name = 's3-pfa'
folder_name = "'Muestreo ct sauce'/'CT S 2023'/S1"
detector_model = '/content/CameraTraps/detection/md_v5a.0.0.pt'
output_file_path = '/content/drive/My Drive/megadetector-results.json'  # Replace with your desired output folder

# Initialize the S3 client
s3 = boto3.client('s3')

# List objects in the S3 folder
response = s3.list_objects_v2(Bucket=bucket_name, Prefix=folder_name)
print(response)
for obj in response.get('Contents', []):
    image_key = obj['Key']
    # Skip directories and non-image files if needed
    if not image_key.endswith('/'):
        # Construct the S3 URL for the image
        s3_url = f's3://{bucket_name}/{image_key}'
        # Run the command for each image
        command = [
            'python',
            '/content/CameraTraps/detection/run_detector_batch.py',
            detector_model,
            s3_url,
            output_file_path,
            '--recursive',
            '--output_relative_filenames',
            '--quiet'
        ]
        subprocess.run(command)

print("Processing complete.")
# Out:
# {'ResponseMetadata': {'RequestId': '3WFXCKS000J0TVDS', 'HostId': 'Jnix9HPeAa4zDNpPUXmxd0kpoU2Vg5mx5VBSYfM2U6kNHuz1srCVCa25vufiYInOU2sGqC3IApoSPzFuUPfnMQ==', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'Jnix9HPeAa4zDNpPUXmxd0kpoU2Vg5mx5VBSYfM2U6kNHuz1srCVCa25vufiYInOU2sGqC3IApoSPzFuUPfnMQ==', 'x-amz-request-id': '3WFXCKS000J0TVDS', 'date': 'Mon, 18 Sep 2023 22:28:18 GMT', 'x-amz-bucket-region': 'us-east-2', 'content-type': 'application/xml', 'transfer-encoding': 'chunked', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'IsTruncated': False, 'Name': 's3-pfa', 'Prefix': "'Muestreo ct sauce'/'CT S 2023'/S1", 'MaxKeys': 1000, 'EncodingType': 'url', 'KeyCount': 0}
# Processing complete.

# %%
import subprocess
import boto3

# Replace these with your actual values
bucket_name = 's3-pfa'
folder_name = 'Muestreo ct sauce/CT S 2023/S1/'  # Path to your images
detector_model = '/content/CameraTraps/detection/md_v5a.0.0.pt'
output_file_path = '/content/drive/MyDrive/megadetector-results.json'  # Replace with your desired output folder
#visualization_dir = 'your-visualization-folder/'  # Replace with your desired visualization folder

# Initialize the S3 client
s3 = boto3.client('s3')

# List objects in the S3 folder
response = s3.list_objects_v2(Bucket=bucket_name, Prefix=folder_name)

for obj in response.get('Contents', []):
    image_key = obj['Key']
    # Skip directories and non-image files if needed
    if not image_key.endswith('/') and image_key.lower().endswith(('.jpg', '.jpeg', '.png', '.gif', '.bmp')):
        # Construct the S3 URL for the image
        s3_url = f's3://{bucket_name}/{image_key}'
        # Run the command for each image
        command = [
            'python',
            '/content/CameraTraps/md_visualization/visualize_detector_output.py',
            output_file_path,
          #  visualization_dir,
            '--confidence',
            '0.2',
            '--images_dir',
            s3_url
        ]
        subprocess.run(command)

print("Processing complete.")
# Out:
# Processing complete.

# %%
images_dir = sauce_2023

# Choose a location for the output JSON file
output_file_path = '/content/drive/My Drive/md_sauce_2023.json'
