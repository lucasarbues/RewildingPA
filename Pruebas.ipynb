# %%
# !pip install boto3
# Out:
# Collecting boto3
#   Downloading boto3-1.28.49-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 2.6 MB/s eta 0:00:00
# Collecting botocore<1.32.0,>=1.31.49 (from boto3)
#   Downloading botocore-1.31.49-py3-none-any.whl (11.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 20.6 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.7.0,>=0.6.0 (from boto3)
#   Downloading s3transfer-0.6.2-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.10/dist-packages (from botocore<1.32.0,>=1.31.49->boto3) (2.8.2)
# Collecting urllib3<1.27,>=1.25.4 (from botocore<1.32.0,>=1.31.49->boto3)
#   Downloading urllib3-1.26.16-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.1/143.1 kB 13.2 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.32.0,>=1.31.49->boto3) (1.16.0)
# Installing collected packages: urllib3, jmespath, botocore, s3transfer, boto3
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.4
#     Uninstalling urllib3-2.0.4:
#       Successfully uninstalled urllib3-2.0.4
# Successfully installed boto3-1.28.49 botocore-1.31.49 jmespath-1.0.1 s3transfer-0.6.2 urllib3-1.26.16

# %%
import boto3
import pandas as pd
from IPython.display import display
from io import BytesIO
import requests

# %%
# Configura tus credenciales de AWS si aún no lo has hecho
boto3.setup_default_session(aws_access_key_id='AKIAQK4VVXEU755YCDOR',
                           aws_secret_access_key='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',
                           region_name='us-east-2')

# %%
# Nombre del bucket
nombre_bucket_s3 = 's3-pfa'

# %%
# Crea un cliente de S3
s3 = boto3.client('s3')

# %% [markdown]
# ### Analizamos base 'Movimiento Camaras'

# %%
# ruta al archivo Excel en S3
ruta_archivo_s3 = 'movimiento camaras.xlsx'

# %%
# Descarga el archivo desde S3
response = s3.get_object(Bucket=nombre_bucket_s3, Key=ruta_archivo_s3)

# %%
# Lee el contenido del archivo Excel en un DataFrame de Pandas
excel_data = response['Body'].read()
df = pd.read_excel(BytesIO(excel_data))

# %%
df
# Out:
#                    Fecha  #camara  sector fecha inicio fecha retiro  \
# 0                14/6/22     33.0       5   2022-06-12   2022-06-14
# 1                14/6/22     14.0       5   2022-06-12   2022-06-14
# 2                14/6/22     23.0       5   2022-06-12   2022-06-14
# 3                14/6/22     31.0       5   2022-06-12   2022-06-14
# 4                14/6/22     21.0       5   2022-06-12   2022-06-14
# ..                   ...      ...     ...          ...          ...
# 357  2022-07-30 00:00:00     43.0       9   2022-07-27   2022-07-30
# 358  2022-07-30 00:00:00     16.0       9   2022-07-27   2022-07-30
# 359  2022-07-30 00:00:00     34.0       9   2022-07-27   2022-07-30
# 360  2022-07-30 00:00:00     42.0       9   2022-07-27   2022-07-30
# 361                  NaN      NaN      10   2022-07-30          NaT
#
#      condicion imágenes #                                Horario  \
# 0     Inactiva        NaN                                    NaN
# 1       Activa        NaN                               18:00:00
# 2     Inactiva        NaN                                    NaN
# 3     Inactiva        NaN                                    NaN
# 4     Inactiva        NaN                                    NaN
# ..         ...        ...                                    ...
# 357  Inactiva         NaN                                    NaN
# 358    Activa         NaN                     27/7  a las 22:30
# 359    Activa         NaN  27/7 a las 22:03 y el 29/7 a las 6:36
# 360    Activa         NaN                       29/7 a las 7:56
# 361        NaN        NaN                                    NaN
#
#              observaciones
# 0     No se observó conejo
# 1                 1 conejo
# 2     No se observó conejo
# 3     No se observó conejo
# 4     No se observó conejo
# ..                     ...
# 357                    NaN
# 358  Se observó un conejo.
# 359  Se observó un conejo.
# 360  Se observó un conejo.
# 361                    NaN
#
# [362 rows x 9 columns]

# %% [markdown]
# ### Analizamos Base 'Muestreo_CT_ParAzul'

# %%
ruta_archivo_s3 = 'Muestreo_CT_PatAzul_2020-2023.xlsx'

# %%
# Descarga el archivo desde S3
response = s3.get_object(Bucket=nombre_bucket_s3, Key=ruta_archivo_s3)

# %%
# Lee el contenido del archivo Excel en un DataFrame de Pandas
excel_data = response['Body'].read()
df2 = pd.read_excel(BytesIO(excel_data))

# %%
df2
# Out:
#         Sitio   Año Cámara  Especie  Cantidad          Nombre      Fecha  \
# 0       Sauce  2020     S1  Guanaco       1.0   0-S1- (3).JPG 2020-02-05
# 1       Sauce  2020     S1  Guanaco       1.0   0-S1- (4).JPG 2020-02-05
# 2       Sauce  2020     S1  Guanaco       1.0   0-S1- (5).JPG 2020-02-05
# 3       Sauce  2020     S1  Guanaco       1.0   0-S1- (6).JPG 2020-02-05
# 4       Sauce  2020     S1  Guanaco       4.0   0-S1- (7).JPG 2020-02-05
# ...       ...   ...    ...      ...       ...             ...        ...
# 2643  Ibérica  2022    IB7  Choique       1.0   IB 22 (6).JPG 2022-05-05
# 2644  Ibérica  2022    IB7  Choique       1.0  IB 22 (11).JPG 2022-05-13
# 2645  Ibérica  2022    IB7  Choique       1.0  IB 22 (15).JPG 2022-05-13
# 2646  Ibérica  2022    IB7  Guanaco       1.0  IB 22 (22).JPG 2022-05-14
# 2647  Ibérica  2022    IB8  Choique       2.0   IB 22 (6).JPG 2022-04-29
#
#            Hora  Unnamed: 8  Unnamed: 9  Unnamed: 10 Unnamed: 11
# 0      20:46:22         NaN         NaN          NaN         NaN
# 1      20:47:10         NaN         NaN          NaN         NaN
# 2      20:47:12         NaN         NaN          NaN         NaN
# 3      20:47:16         NaN         NaN          NaN         NaN
# 4      20:51:48         NaN         NaN          NaN         NaN
# ...         ...         ...         ...          ...         ...
# 2643   17:57:50         NaN         NaN          NaN         NaN
# 2644    8:30:26         NaN         NaN          NaN         NaN
# 2645    8:30:34         NaN         NaN          NaN         NaN
# 2646    8:35:10         NaN         NaN          NaN         NaN
# 2647   17:09:26         NaN         NaN          NaN         NaN
#
# [2648 rows x 12 columns]

# %%
df2['Sitio'].value_counts()
# Out:
# Sauce      2300
# Ibérica     348
# Name: Sitio, dtype: int64

# %%
df2['Especie'].unique()
# Out:
# array(['Guanaco', 'Zorro Gris', 'Martineta', 'Choique', 'Gato montés',
#        'passeriforme', 'Liebre', 'peludo', 'Mara', 'Tucuquere',
#        'Passeriforme', 'Gaviota', 'Jote', 'Peludo', 'Piche', 'Chimango',
#        'Ave S/I', 'Flamenco', 'Aguila Mora', 'Zorrino', 'Puma', 'Pato',
#        'Garza Blanca', 'Halcon', 'atahacaminos', 'Bandurrita', 'Chingolo',
#        'Ratón', 'Loica', 'Calandria ', 'Zorzal chiguanco',
#        'Zorzal Chiguanco', 'Oveja', 'Yal negro', 'Zorrino ', 'Torcaza',
#        'Zorro Colorado', 'Carancho', 'Bandurria', 'Aguilucho Comun',
#        'Cormoran Imperial', 'Cauquen'], dtype=object)

# %% [markdown]
# ### Obtengo una Imagen de Muestra

# %%
ruta_imagen_s3 = "Muestreo ct Iberica/2022/Ib-22 (1)/IMG_0057.JPG"

# %%
# Descarga la imagen desde S3
response = s3.get_object(Bucket=nombre_bucket_s3, Key=ruta_imagen_s3)

# %%
# Lee los datos de la imagen
datos_imagen = response['Body'].read()

# %%
# Abre la imagen utilizando Pillow
imagen = Image.open(BytesIO(datos_imagen))

# Muestra la imagen en el Jupyter Notebook
display(imagen)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-a89bccd09787> in <cell line: 2>()
#       1 # Abre la imagen utilizando Pillow
# ----> 2 imagen = Image.open(BytesIO(datos_imagen))
#       3
#       4 # Muestra la imagen en el Jupyter Notebook
#       5 display(imagen)
#
# NameError: name 'Image' is not defined
